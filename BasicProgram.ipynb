# %%
#Simple Calculator
a=float(input('Enter a First Number:'))
b=float(input('Enter a Second Number:'))
print('\nChoose an option','\n1.Addition','\n2.Subtraction','\n3.Multiplication','\n4.Division')
choice=int(input('\nEnter your choice (1-4):'))
if choice==1:
    print('Sum of',a,'and',b,'is',a+b)
elif choice==2:
    print('Subtraction of',a,'and',b,'is',a-b)
elif choice==3:
    print('Multiplication of',a,'and',b,'is',a*b)
elif choice==4:
    if b!=0:
        print('Division of',a,'and',b,'is',a/b)
    else:
        print('You cannot divide a no by 0')
else:
    print('Invalid choice')
# Out:
# Enter a First Number: 20
# Enter a Second Number: 705
# Choose an option
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# Enter your choice (1-4): 3
# Multiplication of 20.0 and 705.0 is 14100.0

# %%
#To check Number is Wheather the number is Positive,Negetive or Zero
num=float(input("Enter a Number:"))
if num>0:
  print("The given number is Positive")
elif num<0:
  print("The given number is Negetive")
else:
    print("The Given Number is Zero")
# Out:
# Enter a Number: -345
# The given number is Negetive

# %%
#Summation of Digit
num=int(input("Enter a number"))
sum=0
while num>0:
    digit=num%10
    sum=sum+digit
    num=
