# %%
#1. Write a program to add a key and value to a dictionary.

my_dict={0:10,1:20}
my_dict[2]=30
print("Dictionary:",my_dict)
# Out:
# Dictionary: {0: 10, 1: 20, 2: 30}

# %%
#2. Write a program to concatanate the following dictionaries to create a new one.

dict1={1:10,2:20}
dict2={3:30,4:40}
dict3={5:50,6:60}
new_dict={}
new_dict.update(dict1)
new_dict.update(dict2)
new_dict.update(dict3)
print("New Dictionary",new_dict)
# Out:
# New Dictionary {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
#3 Write a program to Check if a given key already exists in a dictionary

my_dict={101:"Amit",102:"Rahul",103:"Manan"}
key=int(input("Enter a key to search:"))
if key in my_dict:
    print("Key exists in the Dictionary")
else:
    print("Key does not exist in the Dictionary")
# Out:
# Enter a key to search: 102
# Key exists in the Dictionary

# %%
#4 Write a progam to iterate over a dictionary using for loop and print the keys alone,values alone and both keys and values

my_dict={
    101:"Amit",
    102:"Rahul",
    103:"Manan"
}
print("Keys:")
for key in my_dict:
    print(key)
print("\nValues:")
for value in my_dict.values():
    print(value)
print("\nKeys and Values:")
for key,value in my_dict.items():
    print(key,value)
# Out:
# Keys:
# 101
# 102
# 103
#
# Values:
# Amit
# Rahul
# Manan
#
# Keys and Values:
# 101 Amit
# 102 Rahul
# 103 Manan

# %%
#5 Write a program to prepare a dictionary where the keys are numbers between 1 and 15(Incl) and the values are the square of the keys.

my_dict={}
for i in range(1,16):
  my_dict[i]=i*2
print(my_dict)
# Out:
# {1: 2, 2: 4, 3: 6, 4: 8, 5: 10, 6: 12, 7: 14, 8: 16, 9: 18, 10: 20, 11: 22, 12: 24, 13: 26, 14: 28, 15: 30}

# %%
#6 Write a program to sum all the values in a dictionary, considering the value will be of int type

my_dict={"a":10,"b":20,"c":30,"d":40}
total=0
for value in my_dict.values():
    total=total+value
print("Sum of Values:",total)
# Out:
# Sum of Values: 100

# %%
#7 Assign 5 elements in dictionary named my_dict. This dictionary contains student information. Add delete student info from my_dict. Display student info

my_dict = {
    101: {"name": "Amit", "age": 20, "grade": "A"},
    102: {"name": "Priya", "age": 21, "grade": "B"},
    103: {"name": "Rahul", "age": 19, "grade": "A"},
    104: {"name": "Sneha", "age": 22, "grade": "C"},
    105: {"name": "Vikram", "age": 20, "grade": "B"}
}
new_student_id = 106
my_dict[new_student_id] = {"name": "Kiran", "age": 21, "grade": "A"}
student_del = 103
if student_del in my_dict:
    del my_dict[student_del]
else:
    print(f"Student ID {student_del} not found.")
print("Student Information:")
for student_id, info in my_dict.items():
    print(f"ID: {student_id}, Name: {info['name']}, Age: {info['age']}, Grade: {info['grade']}")
# Out:
# Student Information:
# ID: 101, Name: Amit, Age: 20, Grade: A
# ID: 102, Name: Priya, Age: 21, Grade: B
# ID: 104, Name: Sneha, Age: 22, Grade: C
# ID: 105, Name: Vikram, Age: 20, Grade: B
# ID: 106, Name: Kiran, Age: 21, Grade: A

# %%
#8 Convert List to Dictionary

# %%
#9 Convert Dictionary to List

# %%
#10 Find Mean of values of dictionary

# %%
#12 Write a python program to create dictionary of 5 elements with marks and display the student with the highest marks

students = {
    'Manan': 85,
    'BoB': 92,
    'Joe': 78,
    'David': 90,
    'Donald': 88
}
top_student = max(students, key=students.get)
highest_marks = students[top_student]

# Display the result
print(f"Student with highest marks: {top_student}")
print(f"Highest Marks: {highest_marks}")

# %%
#13 Python program to count the frequency of each element in a list using a dictionary

my_list = ['apple', 'banana', 'apple', 'orange', 'banana', 'banana']
freq_dict = {}

for item in my_list:
    freq_dict[item] = freq_dict.get(item, 0) + 1

print("Frequency of the elements:",freq_dict)

# %%
#14 Python Program to sort a dictionary by its value

my_dict = {'Manan': 85, 'Bob': 92, 'Chaganlal': 78, 'Duck': 95}
sorted_dict = dict(sorted(my_dict.items(), key=lambda item: item[1]))
print("Dictionary sorted by Values")
print(sorted_dict)
