# %%
score = float(input("Enter Score: "))
attendance = float(input("Enter Attendance: "))

if score >= 70:
    print("Student passed the exam.")

    if attendance >= 90:
        print("Student also has excellent attendance.")
    else:
        print("Student attendance very low. Very disappointed.")
else:
    print("Student did not pass the exam.")
# Out:
# Enter Score:  89
# Enter Attendance:  54
# Student passed the exam.
# Student attendance very low. Very disappointed.

# %%
fruit=["apple","banana","orange"]
for fruits in fruit:
    print(fruits)
# Out:
# apple
# banana
# orange

# %%
count=0
while count<5:
    print(count)
    count+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
adj=["red","big","tasty"]
fruits=["Apple","banana","cherry"]
for x in adj:
    for y in fruits:
        print(x, y)
# Out:
# red Apple
# red banana
# red cherry
# big Apple
# big banana
# big cherry
# tasty Apple
# tasty banana
# tasty cherry

# %%
for i in range(10):
    if i==5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    if i==2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4
